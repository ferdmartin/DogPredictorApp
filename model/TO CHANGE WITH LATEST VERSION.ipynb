# %%
# import os
# import numpy as np
# import tensorflow as tf

# #data_dir = pathlib.Path('low-resolution')
# os.chdir('low-resolution')

# # Rename folders
# [os.rename(item, item.split('-')[-1]) for item in os.listdir()]
# # Delete odd file
# os.remove('~$directoryfilecount.xlsx')
#[os.rename(os.path.join('data',item), os.path.join('data',item.split('-')[-1])) for item in os.listdir('data')]

# Data: https://cg.cs.tsinghua.edu.cn/ThuDogs/

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mping
import random
import json

# %%
os.chdir('/Users/femartinez/Documents/Dog_breeds_project/Dog_Breeds_App/')
class_names = os.listdir()
class_names.remove('.DS_Store')
class_names = np.array(sorted(class_names)) # Created a list of class_names from the subdirectory in the train folder
len(class_names)
# Out:
# 129

# %%
os.chdir('/Users/femartinez/Documents/Dog_breeds_project/Dog_Breeds_App/')

# %%
# Create validation set

# dog_breeds_validation = os.listdir('validation-low-resolution')

# for _ in range(validation_set_size):
#     dog_breed = random.choice(class_names)
#     
#     if dog_breed not in dog_breeds_validation:
#         os.mkdir(os.path.join(os.getcwd(),'validation-low-resolution',dog_breed))
#         dog_breeds_validation.append(dog_breed)
        
#     picked_image = random.choice(os.listdir(os.path.join(os.getcwd(),'low-resolution',dog_breed)))
    
#     os.rename(os.path.join(os.getcwd(),'low-resolution', dog_breed,picked_image), 
#               os.path.join(os.getcwd(),'validation-low-resolution', dog_breed,picked_image))

# %%
def view_image(path):

  import matplotlib.pyplot as plt
  import matplotlib.image as mpimg

  img = mpimg.imread(path)
  plt.imshow(img)
  plt.axis(False);
  #plt.title(f'{path}')

# %%
img_path = '/content/low-resolution/Border_collie/n133496.jpg'
# Create a function to import an image and resize it to be used with our model
def load_and_prep_image(filename, img_shape=224):
  '''
  Reads an image from filename, turns it into a tensor and reshapes it to (img_shape, img_shape, colour_channels)
  '''
  # read in the image
  img = tf.io.read_file(filename)
  # Decode the read file into -- turn it into a tensor
  img = tf.image.decode_image(img)
  # Resize the image
  img = tf.image.resize(img, size = [img_shape,img_shape])
  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  
  img = tf.expand_dims(img, axis=0)
  return img

# %%
os.getcwd()
# Out:
# '/Users/femartinez/Documents/Dog_breeds_project/Dog_Breeds_App'

# %%
IMG_SIZE = (224,224)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(os.getcwd(),'model/data_dogs'),
    validation_split=0.10,
    subset="training",
    seed=90,
    image_size=IMG_SIZE,
    batch_size=32,
    label_mode = 'categorical')

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(os.getcwd(),'model/data_dogs'),
    validation_split=0.10,
    subset="validation",
    seed=90,
    image_size=IMG_SIZE,
    batch_size=32,
    label_mode = 'categorical')
# Out:
# Found 67104 files belonging to 129 classes.
# Using 58381 files for training.
# Found 67104 files belonging to 129 classes.
# Using 8052 files for validation.

# %%
import json
classes_as_dict = dict(zip(range(len(train_ds.class_names)), train_ds.class_names))

with open('classes_dict.json', 'w') as jf:
    json.dump(classes_as_dict, jf)
# Create json file with classes

# %%
with open('/Users/femartinez/Documents/Dog_breeds_project/Dog_Breeds_App/model/classes_dict.json') as classes:
        class_names = json.load(classes)

# %%
from tensorflow.keras.layers.experimental import preprocessing
data_augmentation = tf.keras.Sequential([
                                         tf.keras.layers.RandomFlip('horizontal_and_vertical'),
                                         preprocessing.RandomRotation(0.32),
                                         preprocessing.RandomZoom(0.32),
                                         preprocessing.RandomHeight(0.32),
                                         preprocessing.RandomWidth(0.32)
], name="data_augmentation")

# %%
target_class = random.choice(class_names)
random_image = f'{os.getcwd()}/data/{target_class}/{random.choice(os.listdir("data/"+target_class))}'
img1 = tf.io.read_file(random_image)

img_tensor = mping.imread(random_image)

plt.imshow(img_tensor/255.)
plt.title(f'{target_class}')
plt.axis(False);

img_augmented = data_augmentation(tf.expand_dims(img_tensor, axis=0), training=True)
plt.figure()
plt.imshow(tf.squeeze(img_augmented)/255.)
plt.title(f'{target_class}')
plt.axis(False);

# %%
base_model = tf.keras.applications.EfficientNetB3(include_top=False)
base_model.trainable = False

input_shape = IMG_SIZE+(3,)

inputs = tf.keras.layers.Input(shape=input_shape, name="Input_layer")

x = data_augmentation(inputs)
x = base_model(inputs, training=False) # Pass the augmented images to base model but keep it in inference mode, this also insures batchnorm layers don't get updated
x = tf.keras.layers.GlobalAveragePooling2D(name="Global_Average_Pooling_Layer")(x)
outputs = tf.keras.layers.Dense(len(class_names), activation="softmax", name="Output_layer")(x)
model_1 = tf.keras.Model(inputs, outputs)

model_1.compile(loss= tf.keras.losses.categorical_crossentropy,
                optimizer = tf.keras.optimizers.Adam(),
                metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 1s 0us/step

# %%
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  efficientnetb3 (Functional)  (None, None, None, 1536)  10783535
#
#  Global_Average_Pooling_Laye  (None, 1536)             0
#  r (GlobalAveragePooling2D)
#
#  Output_layer (Dense)        (None, 129)               198273
#
# =================================================================
# Total params: 10,981,808
# Trainable params: 198,273
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
# Set checkpoint path
checkpoint_path = "pechpoints_weights/checkpoint.ckpt"

# Create a ModelCheckpoint callback that saves the model's weights only
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         verbose=1,
                                                         save_weights_only=True,
                                                         save_best_only=True,
                                                         save_freq="epoch")

early_stopper = tf.keras.callbacks.EarlyStopping(patience=3, 
                                                 restore_best_weights=True)

# %%
initial_epochs = 5
history_data_aug = model_1.fit(train_ds,
                               epochs=initial_epochs,
                               steps_per_epoch=len(train_ds),
                               validation_data = val_ds,
                               validation_steps= int(0.40 * len(val_ds)),
                               callbacks=[checkpoint_callback, early_stopper])
# Out:
# Epoch 1/5
# 2022-08-25 16:14:50.603828: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-08-25 16:14:50.609136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1825/1825 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.7968
# 2022-08-25 16:20:40.444615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.52236, saving model to pechpoints_weights/checkpoint.ckpt
# 1825/1825 [==============================] - 373s 202ms/step - loss: 0.7344 - accuracy: 0.7968 - val_loss: 0.5224 - val_accuracy: 0.8388
# Epoch 2/5
# 1825/1825 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8531
# Epoch 2: val_loss improved from 0.52236 to 0.50684, saving model to pechpoints_weights/checkpoint.ckpt
# 1825/1825 [==============================] - 368s 202ms/step - loss: 0.4458 - accuracy: 0.8531 - val_loss: 0.5068 - val_accuracy: 0.8375
# Epoch 3/5
# 1825/1825 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8761
# Epoch 3: val_loss did not improve from 0.50684
# 1825/1825 [==============================] - 367s 201ms/step - loss: 0.3710 - accuracy: 0.8761 - val_loss: 0.5101 - val_accuracy: 0.8388
# Epoch 4/5
# 1825/1825 [==============================] - ETA: 0s - loss: 0.3216 - accuracy: 0.8920
# Epoch 4: val_loss did not improve from 0.50684
# 1825/1825 [==============================] - 370s 203ms/step - loss: 0.3216 - accuracy: 0.8920 - val_loss: 0.5153 - val_accuracy: 0.8325
# Epoch 5/5
# 1825/1825 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.9036
# Epoch 5: val_loss did not improve from 0.50684
# 1825/1825 [==============================] - 369s 202ms/step - loss: 0.2850 - accuracy: 0.9036 - val_loss: 0.5204 - val_accuracy: 0.8347

# %%
# Unfreeze all of the layer in the base model
base_model.trainable = True

# Refreeze every layer except the last 5
for layer in base_model.layers[:-8]:
  layer.trainable = False

# Recompile model with lower learning rate (it's typically best practice to lower the learning rate when fine-tuning)
model_1.compile(loss=tf.keras.losses.categorical_crossentropy,
                optimizer= tf.keras.optimizers.Adam(1.0e-4),
                metrics=["accuracy"])

# %%
for layer in model_1.layers:
  print(layer.name, layer.trainable)
# Out:
# Input_layer True
# efficientnetb3 True
# Global_Average_Pooling_Layer True
# Output_layer True

# %%
for layer_number, layer in enumerate(model_1.layers[1].layers):
  print(f"({layer_number}) {layer.name}: {layer.trainable}")
# Out:
# (0) input_1: False
# (1) rescaling: False
# (2) normalization: False
# (3) tf.math.truediv: False
# (4) stem_conv_pad: False
# (5) stem_conv: False
# (6) stem_bn: False
# (7) stem_activation: False
# (8) block1a_dwconv: False
# (9) block1a_bn: False
# (10) block1a_activation: False
# (11) block1a_se_squeeze: False
# (12) block1a_se_reshape: False
# (13) block1a_se_reduce: False
# (14) block1a_se_expand: False
# (15) block1a_se_excite: False
# (16) block1a_project_conv: False
# (17) block1a_project_bn: False
# (18) block1b_dwconv: False
# (19) block1b_bn: False
# (20) block1b_activation: False
# (21) block1b_se_squeeze: False
# (22) block1b_se_reshape: False
# (23) block1b_se_reduce: False
# (24) block1b_se_expand: False
# (25) block1b_se_excite: False
# (26) block1b_project_conv: False
# (27) block1b_project_bn: False
# (28) block1b_drop: False
# (29) block1b_add: False
# (30) block2a_expand_conv: False
# (31) block2a_expand_bn: False
# (32) block2a_expand_activation: False
# (33) block2a_dwconv_pad: False
# (34) block2a_dwconv: False
# (35) block2a_bn: False
# (36) block2a_activation: False
# (37) block2a_se_squeeze: False
# (38) block2a_se_reshape: False
# (39) block2a_se_reduce: False
# (40) block2a_se_expand: False
# (41) block2a_se_excite: False
# (42) block2a_project_conv: False
# (43) block2a_project_bn: False
# (44) block2b_expand_conv: False
# (45) block2b_expand_bn: False
# (46) block2b_expand_activation: False
# (47) block2b_dwconv: False
# (48) block2b_bn: False
# (49) block2b_activation: False
# (50) block2b_se_squeeze: False
# (51) block2b_se_reshape: False
# (52) block2b_se_reduce: False
# (53) block2b_se_expand: False
# (54) block2b_se_excite: False
# (55) block2b_project_conv: False
# (56) block2b_project_bn: False
# (57) block2b_drop: False
# (58) block2b_add: False
# (59) block2c_expand_conv: False
# (60) block2c_expand_bn: False
# (61) block2c_expand_activation: False
# (62) block2c_dwconv: False
# (63) block2c_bn: False
# (64) block2c_activation: False
# (65) block2c_se_squeeze: False
# (66) block2c_se_reshape: False
# (67) block2c_se_reduce: False
# (68) block2c_se_expand: False
# (69) block2c_se_excite: False
# (70) block2c_project_conv: False
# (71) block2c_project_bn: False
# (72) block2c_drop: False
# (73) block2c_add: False
# (74) block3a_expand_conv: False
# (75) block3a_expand_bn: False
# (76) block3a_expand_activation: False
# (77) block3a_dwconv_pad: False
# (78) block3a_dwconv: False
# (79) block3a_bn: False
# (80) block3a_activation: False
# (81) block3a_se_squeeze: False
# (82) block3a_se_reshape: False
# (83) block3a_se_reduce: False
# (84) block3a_se_expand: False
# (85) block3a_se_excite: False
# (86) block3a_project_conv: False
# (87) block3a_project_bn: False
# (88) block3b_expand_conv: False
# (89) block3b_expand_bn: False
# (90) block3b_expand_activation: False
# (91) block3b_dwconv: False
# (92) block3b_bn: False
# (93) block3b_activation: False
# (94) block3b_se_squeeze: False
# (95) block3b_se_reshape: False
# (96) block3b_se_reduce: False
# (97) block3b_se_expand: False
# (98) block3b_se_excite: False
# (99) block3b_project_conv: False
# (100) block3b_project_bn: False
# (101) block3b_drop: False
# (102) block3b_add: False
# (103) block3c_expand_conv: False
# (104) block3c_expand_bn: False
# (105) block3c_expand_activation: False
# (106) block3c_dwconv: False
# (107) block3c_bn: False
# (108) block3c_activation: False
# (109) block3c_se_squeeze: False
# (110) block3c_se_reshape: False
# (111) block3c_se_reduce: False
# (112) block3c_se_expand: False
# (113) block3c_se_excite: False
# (114) block3c_project_conv: False
# (115) block3c_project_bn: False
# (116) block3c_drop: False
# (117) block3c_add: False
# (118) block4a_expand_conv: False
# (119) block4a_expand_bn: False
# (120) block4a_expand_activation: False
# (121) block4a_dwconv_pad: False
# (122) block4a_dwconv: False
# (123) block4a_bn: False
# (124) block4a_activation: False
# (125) block4a_se_squeeze: False
# (126) block4a_se_reshape: False
# (127) block4a_se_reduce: False
# (128) block4a_se_expand: False
# (129) block4a_se_excite: False
# (130) block4a_project_conv: False
# (131) block4a_project_bn: False
# (132) block4b_expand_conv: False
# (133) block4b_expand_bn: False
# (134) block4b_expand_activation: False
# (135) block4b_dwconv: False
# (136) block4b_bn: False
# (137) block4b_activation: False
# (138) block4b_se_squeeze: False
# (139) block4b_se_reshape: False
# (140) block4b_se_reduce: False
# (141) block4b_se_expand: False
# (142) block4b_se_excite: False
# (143) block4b_project_conv: False
# (144) block4b_project_bn: False
# (145) block4b_drop: False
# (146) block4b_add: False
# (147) block4c_expand_conv: False
# (148) block4c_expand_bn: False
# (149) block4c_expand_activation: False
# (150) block4c_dwconv: False
# (151) block4c_bn: False
# (152) block4c_activation: False
# (153) block4c_se_squeeze: False
# (154) block4c_se_reshape: False
# (155) block4c_se_reduce: False
# (156) block4c_se_expand: False
# (157) block4c_se_excite: False
# (158) block4c_project_conv: False
# (159) block4c_project_bn: False
# (160) block4c_drop: False
# (161) block4c_add: False
# (162) block4d_expand_conv: False
# (163) block4d_expand_bn: False
# (164) block4d_expand_activation: False
# (165) block4d_dwconv: False
# (166) block4d_bn: False
# (167) block4d_activation: False
# (168) block4d_se_squeeze: False
# (169) block4d_se_reshape: False
# (170) block4d_se_reduce: False
# (171) block4d_se_expand: False
# (172) block4d_se_excite: False
# (173) block4d_project_conv: False
# (174) block4d_project_bn: False
# (175) block4d_drop: False
# (176) block4d_add: False
# (177) block4e_expand_conv: False
# (178) block4e_expand_bn: False
# (179) block4e_expand_activation: False
# (180) block4e_dwconv: False
# (181) block4e_bn: False
# (182) block4e_activation: False
# (183) block4e_se_squeeze: False
# (184) block4e_se_reshape: False
# (185) block4e_se_reduce: False
# (186) block4e_se_expand: False
# (187) block4e_se_excite: False
# (188) block4e_project_conv: False
# (189) block4e_project_bn: False
# (190) block4e_drop: False
# (191) block4e_add: False
# (192) block5a_expand_conv: False
# (193) block5a_expand_bn: False
# (194) block5a_expand_activation: False
# (195) block5a_dwconv: False
# (196) block5a_bn: False
# (197) block5a_activation: False
# (198) block5a_se_squeeze: False
# (199) block5a_se_reshape: False
# (200) block5a_se_reduce: False
# (201) block5a_se_expand: False
# (202) block5a_se_excite: False
# (203) block5a_project_conv: False
# (204) block5a_project_bn: False
# (205) block5b_expand_conv: False
# (206) block5b_expand_bn: False
# (207) block5b_expand_activation: False
# (208) block5b_dwconv: False
# (209) block5b_bn: False
# (210) block5b_activation: False
# (211) block5b_se_squeeze: False
# (212) block5b_se_reshape: False
# (213) block5b_se_reduce: False
# (214) block5b_se_expand: False
# (215) block5b_se_excite: False
# (216) block5b_project_conv: False
# (217) block5b_project_bn: False
# (218) block5b_drop: False
# (219) block5b_add: False
# (220) block5c_expand_conv: False
# (221) block5c_expand_bn: False
# (222) block5c_expand_activation: False
# (223) block5c_dwconv: False
# (224) block5c_bn: False
# (225) block5c_activation: False
# (226) block5c_se_squeeze: False
# (227) block5c_se_reshape: False
# (228) block5c_se_reduce: False
# (229) block5c_se_expand: False
# (230) block5c_se_excite: False
# (231) block5c_project_conv: False
# (232) block5c_project_bn: False
# (233) block5c_drop: False
# (234) block5c_add: False
# (235) block5d_expand_conv: False
# (236) block5d_expand_bn: False
# (237) block5d_expand_activation: False
# (238) block5d_dwconv: False
# (239) block5d_bn: False
# (240) block5d_activation: False
# (241) block5d_se_squeeze: False
# (242) block5d_se_reshape: False
# (243) block5d_se_reduce: False
# (244) block5d_se_expand: False
# (245) block5d_se_excite: False
# (246) block5d_project_conv: False
# (247) block5d_project_bn: False
# (248) block5d_drop: False
# (249) block5d_add: False
# (250) block5e_expand_conv: False
# (251) block5e_expand_bn: False
# (252) block5e_expand_activation: False
# (253) block5e_dwconv: False
# (254) block5e_bn: False
# (255) block5e_activation: False
# (256) block5e_se_squeeze: False
# (257) block5e_se_reshape: False
# (258) block5e_se_reduce: False
# (259) block5e_se_expand: False
# (260) block5e_se_excite: False
# (261) block5e_project_conv: False
# (262) block5e_project_bn: False
# (263) block5e_drop: False
# (264) block5e_add: False
# (265) block6a_expand_conv: False
# (266) block6a_expand_bn: False
# (267) block6a_expand_activation: False
# (268) block6a_dwconv_pad: False
# (269) block6a_dwconv: False
# (270) block6a_bn: False
# (271) block6a_activation: False
# (272) block6a_se_squeeze: False
# (273) block6a_se_reshape: False
# (274) block6a_se_reduce: False
# (275) block6a_se_expand: False
# (276) block6a_se_excite: False
# (277) block6a_project_conv: False
# (278) block6a_project_bn: False
# (279) block6b_expand_conv: False
# (280) block6b_expand_bn: False
# (281) block6b_expand_activation: False
# (282) block6b_dwconv: False
# (283) block6b_bn: False
# (284) block6b_activation: False
# (285) block6b_se_squeeze: False
# (286) block6b_se_reshape: False
# (287) block6b_se_reduce: False
# (288) block6b_se_expand: False
# (289) block6b_se_excite: False
# (290) block6b_project_conv: False
# (291) block6b_project_bn: False
# (292) block6b_drop: False
# (293) block6b_add: False
# (294) block6c_expand_conv: False
# (295) block6c_expand_bn: False
# (296) block6c_expand_activation: False
# (297) block6c_dwconv: False
# (298) block6c_bn: False
# (299) block6c_activation: False
# (300) block6c_se_squeeze: False
# (301) block6c_se_reshape: False
# (302) block6c_se_reduce: False
# (303) block6c_se_expand: False
# (304) block6c_se_excite: False
# (305) block6c_project_conv: False
# (306) block6c_project_bn: False
# (307) block6c_drop: False
# (308) block6c_add: False
# (309) block6d_expand_conv: False
# (310) block6d_expand_bn: False
# (311) block6d_expand_activation: False
# (312) block6d_dwconv: False
# (313) block6d_bn: False
# (314) block6d_activation: False
# (315) block6d_se_squeeze: False
# (316) block6d_se_reshape: False
# (317) block6d_se_reduce: False
# (318) block6d_se_expand: False
# (319) block6d_se_excite: False
# (320) block6d_project_conv: False
# (321) block6d_project_bn: False
# (322) block6d_drop: False
# (323) block6d_add: False
# (324) block6e_expand_conv: False
# (325) block6e_expand_bn: False
# (326) block6e_expand_activation: False
# (327) block6e_dwconv: False
# (328) block6e_bn: False
# (329) block6e_activation: False
# (330) block6e_se_squeeze: False
# (331) block6e_se_reshape: False
# (332) block6e_se_reduce: False
# (333) block6e_se_expand: False
# (334) block6e_se_excite: False
# (335) block6e_project_conv: False
# (336) block6e_project_bn: False
# (337) block6e_drop: False
# (338) block6e_add: False
# (339) block6f_expand_conv: False
# (340) block6f_expand_bn: False
# (341) block6f_expand_activation: False
# (342) block6f_dwconv: False
# (343) block6f_bn: False
# (344) block6f_activation: False
# (345) block6f_se_squeeze: False
# (346) block6f_se_reshape: False
# (347) block6f_se_reduce: False
# (348) block6f_se_expand: False
# (349) block6f_se_excite: False
# (350) block6f_project_conv: False
# (351) block6f_project_bn: False
# (352) block6f_drop: False
# (353) block6f_add: False
# (354) block7a_expand_conv: False
# (355) block7a_expand_bn: False
# (356) block7a_expand_activation: False
# (357) block7a_dwconv: False
# (358) block7a_bn: False
# (359) block7a_activation: False
# (360) block7a_se_squeeze: False
# (361) block7a_se_reshape: False
# (362) block7a_se_reduce: False
# (363) block7a_se_expand: False
# (364) block7a_se_excite: False
# (365) block7a_project_conv: False
# (366) block7a_project_bn: False
# (367) block7b_expand_conv: False
# (368) block7b_expand_bn: False
# (369) block7b_expand_activation: False
# (370) block7b_dwconv: False
# (371) block7b_bn: False
# (372) block7b_activation: False
# (373) block7b_se_squeeze: False
# (374) block7b_se_reshape: False
# (375) block7b_se_reduce: False
# (376) block7b_se_expand: False
# (377) block7b_se_excite: True
# (378) block7b_project_conv: True
# (379) block7b_project_bn: True
# (380) block7b_drop: True
# (381) block7b_add: True
# (382) top_conv: True
# (383) top_bn: True
# (384) top_activation: True

# %%
fine_tune_epochs = initial_epochs+5

history_fine_tune = model_1.fit(train_ds,
                                epochs=fine_tune_epochs,
                                initial_epoch= history_data_aug.epoch[-1],
                                validation_data = val_ds,
                                validation_steps= int(0.40 * len(val_ds)),
                                callbacks=[early_stopper])
# Out:
# Epoch 5/10
# 2022-08-25 16:50:14.939464: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1825/1825 [==============================] - ETA: 0s - loss: 0.3456 - accuracy: 0.8828
# 2022-08-25 16:56:15.806556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1825/1825 [==============================] - 384s 208ms/step - loss: 0.3456 - accuracy: 0.8828 - val_loss: 0.4903 - val_accuracy: 0.8416
# Epoch 6/10
# 1825/1825 [==============================] - 372s 204ms/step - loss: 0.2635 - accuracy: 0.9113 - val_loss: 0.4936 - val_accuracy: 0.8428
# Epoch 7/10
# 1825/1825 [==============================] - 371s 203ms/step - loss: 0.2077 - accuracy: 0.9325 - val_loss: 0.5151 - val_accuracy: 0.8375
# Epoch 8/10
# 1825/1825 [==============================] - 372s 204ms/step - loss: 0.1662 - accuracy: 0.9460 - val_loss: 0.5252 - val_accuracy: 0.8328

# %%
model_1.evaluate(val_ds)
# Out:
# 252/252 [==============================] - 51s 198ms/step - loss: 0.5046 - accuracy: 0.8354
# [0.5045922994613647, 0.8354446291923523]

# %%
model_1.save(os.path.join(os.getcwd(),'saved_model.h5'))

# %%
saved_model = tf.keras.models.load_model(os.path.join(os.getcwd(),'saved_model.h5'))
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-08-26 00:05:46.104717: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-26 00:05:46.104840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
saved_model.evaluate(val_ds)
# Out:
# 2022-08-25 17:20:48.389466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 252/252 [==============================] - 52s 197ms/step - loss: 0.5046 - accuracy: 0.8354
# [0.50459223985672, 0.8354446291923523]

# %%
def load_and_prep_image(filename, img_shape=224, scale=True):
  from PIL import Image
  """
  Reads in an image from filename, turns it into a tensor and reshapes into
  specified shape (img_shape, img_shape, color_channels=3).

  Args:
    filename (str): path to target image
    img_shape (int): height/width dimension of target image size
    scale (bool): scale pixel values from 0-255 to 0-1 or not

  Returns:
    Image tensor of shape (img_shape,img_shape,3)
  """
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode image into a tensor
  img = tf.io.decode_image(img, channels=3)
  # Resize our image
  img = tf.image.resize(img, [img_shape,img_shape])
  # Scale
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/225.
  else:
    return img # don't need to resclae images for EfficientNet models in Tensorflow

# %%
saved_model = tf.keras.models.load_model(os.path.join(os.getcwd(),'saved_model.h5'))

# %%
image_to_test = load_and_prep_image('/Users/femartinez/Desktop/lyanne.jpeg', scale=False)

prediction = saved_model.predict(tf.expand_dims(image_to_test, axis=0), verbose=0)
plt.imshow(image_to_test/255.)
plt.title(f'Breed Prediction: {class_names[str(tf.argmax(prediction, axis=1).numpy()[0])]}')
plt.axis(False);

# %%
tf.argmax(prediction, axis=1).numpy()
# Out:
# array([ 12,  27,   9,  80,  44, 119,  62])

# %%
test_preds = model_1.predict(val_ds, verbose=1)
# Out:
# 2022-08-21 22:00:35.274009: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 273/273 [==============================] - 46s 151ms/step

# %%
val_ds.class_names
# Out:
# ['Afghan_hound',
#  'African_hunting_dog',
#  'Airedale',
#  'American_Staffordshire_terrier',
#  'Appenzeller',
#  'Australian_Shepherd',
#  'Australian_terrier',
#  'Bedlington_terrier',
#  'Bernese_mountain_dog',
#  'Bichon_Frise',
#  'Black_sable',
#  'Blenheim_spaniel',
#  'Border_collie',
#  'Border_terrier',
#  'Boston_bull',
#  'Bouvier_des_Flandres',
#  'Brabancon_griffo',
#  'Brittany_spaniel',
#  'Cane_Carso',
#  'Cardigan',
#  'Chesapeake_Bay_retriever',
#  'Chihuahua',
#  'Chinese_Crested_Dog',
#  'Dandie_Dinmont',
#  'Doberman',
#  'English_foxhound',
#  'English_setter',
#  'English_springer',
#  'EntleBucher',
#  'Eskimo_dog',
#  'Fila Braziliero',
#  'French_bulldog',
#  'German_shepherd',
#  'German_short_haired_pointer',
#  'Gordon_setter',
#  'Great_Dane',
#  'Great_Pyrenees',
#  'Greater_Swiss_Mountain_dog',
#  'Ibizan_hound',
#  'Irish_setter',
#  'Irish_terrier',
#  'Irish_water_spaniel',
#  'Irish_wolfhound',
#  'Italian_greyhound',
#  'Japanese_Spitzes',
#  'Japanese_spaniel',
#  'Kerry_blue_terrier',
#  'Labrador_retriever',
#  'Lakeland_terrier',
#  'Leonberg',
#  'Lhasa',
#  'Maltese_dog',
#  'Mexican_hairless',
#  'Newfoundland',
#  'Norfolk_terrier',
#  'Norwegian_elkhound',
#  'Norwich_terrier',
#  'Old_English_sheepdog',
#  'Pekinese',
#  'Pembroke',
#  'Pomeranian',
#  'Rhodesian_ridgeback',
#  'Rottweiler',
#  'Saint_Bernard',
#  'Saluki',
#  'Samoyed',
#  'Scotch_terrier',
#  'Scottish_deerhound',
#  'Sealyham_terrier',
#  'Shetland_sheepdog',
#  'Shiba_Dog',
#  'Shih_Tzu',
#  'Siberian_husky',
#  'Staffordshire_bullterrier',
#  'Sussex_spaniel',
#  'Tibetan_mastiff',
#  'Tibetan_terrier',
#  'Walker_hound',
#  'Weimaraner',
#  'Welsh_springer_spaniel',
#  'West_Highland_white_terrier',
#  'Yorkshire_terrier',
#  'affenpinscher',
#  'basenji',
#  'basset',
#  'beagle',
#  'black_and_tan_coonhound',
#  'bloodhound',
#  'bluetick',
#  'borzoi',
#  'boxer',
#  'briard',
#  'bull_mastiff',
#  'cairn',
#  'chow',
#  'clumber',
#  'cocker_spaniel',
#  'collie',
#  'curly_coated_retriever',
#  'dhole',
#  'dingo',
#  'flat_coated_retriever',
#  'giant_schnauzer',
#  'golden_retriever',
#  'groenendael',
#  'keeshond',
#  'kelpie',
#  'komondor',
#  'kuvasz',
#  'malamute',
#  'malinois',
#  'miniature_pinscher',
#  'miniature_poodle',
#  'miniature_schnauzer',
#  'otterhound',
#  'papillon',
#  'pug',
#  'redbone',
#  'schipperke',
#  'silky_terrier',
#  'soft_coated_wheaten_terrier',
#  'standard_poodle',
#  'standard_schnauzer',
#  'teddy',
#  'toy_poodle',
#  'toy_terrier',
#  'vizsla',
#  'whippet',
#  'wire_haired_fox_terrier']

# %%
tf.argmax(test_preds,axis=1)
# Out:
# <tf.Tensor: shape=(8722,), dtype=int64, numpy=array([103, 104,  65, ..., 123,  45,  33])>

# %%
import os

# %%
tf.argmax(prediction,axis=1).numpy()[0]
# Out:
# 5

# %%
from pathlib import Path
os.path.join(Path('__file__').parent.absolute(), 'mogola')
# Out:
# '/Users/femartinez/Documents/Dog_breeds_project/Dog_Breeds_App/model/mogola'
